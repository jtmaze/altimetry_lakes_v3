# %% [markdown]
# ### 1.0 Libraries and Directories

# %%
import ee
import geemap
import pprint as pp

# %%
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_0JLhFqfSY1uiEaW?source=Init

# %%
glad = ee.ImageCollection('projects/glad/water/individualMonths')

rois = ee.data.listAssets('projects/alpod-412314/assets/ROIs/')
rois_ids = [roi['id'] for roi in rois['assets']]
rois_ids.remove('projects/alpod-412314/assets/ROIs/all_regions')
pp.pp(rois_ids)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['projects/alpod-412314/assets/ROIs/AKCP_roi',
#  'projects/alpod-412314/assets/ROIs/MRD_TUK_Anderson_roi',
#  'projects/alpod-412314/assets/ROIs/MRD_roi',
#  'projects/alpod-412314/assets/ROIs/TUK_roi',
#  'projects/alpod-412314/assets/ROIs/YKdelta_roi',
#  'projects/alpod-412314/assets/ROIs/YKflats_roi',
#  'projects/alpod-412314/assets/ROIs/anderson_plain_roi']

# %% [markdown]
# ### 2.0 Combine all the GLAD observations for June & August for 20 years.

# %%
years = range(1990, 2025) # 2016-2020 is the common timeframe | 1999-2020 is the full timeframe

aug_sys_idx =[f'{year}_08' for year in years]
june_sys_idx =[f'{year}_06' for year in years]

jun_imgs = glad.filter(ee.Filter.inList('system:index', june_sys_idx))
jun_max_obs = jun_imgs.size().getInfo()
aug_imgs = glad.filter(ee.Filter.inList('system:index', aug_sys_idx))
aug_max_obs = aug_imgs.size().getInfo()

monthly_datasets = [
    (jun_imgs, jun_max_obs, 'june'), 
    (aug_imgs, aug_max_obs, 'aug'),
]

print(jun_max_obs, aug_max_obs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 22 22

# %%
pp.pp(jun_imgs.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'ImageCollection',
#  'bands': [],
#  'version': 1647386366866962,
#  'id': 'projects/glad/water/individualMonths',
#  'features': [{'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794621811240.0,
#                'id': 'projects/glad/water/individualMonths/1999_06',
#                'properties': {'system:time_start': 929404800000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 6177697201,
#                               'system:index': '1999_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794661934612,
#                'id': 'projects/glad/water/individualMonths/2000_06',
#                'properties': {'system:time_start': 961027200000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 9437740186,
#                               'system:index': '2000_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794701343700.0,
#                'id': 'projects/glad/water/individualMonths/2001_06',
#                'properties': {'system:time_start': 992563200000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 9222058883,
#                               'system:index': '2001_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794739598642,
#                'id': 'projects/glad/water/individualMonths/2002_06',
#                'properties': {'system:time_start': 1024099200000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 9465874485,
#                               'system:index': '2002_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794779351820.0,
#                'id': 'projects/glad/water/individualMonths/2003_06',
#                'properties': {'system:time_start': 1055635200000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 3215147815,
#                               'system:index': '2003_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794817171900.0,
#                'id': 'projects/glad/water/individualMonths/2004_06',
#                'properties': {'system:time_start': 1087257600000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 11334327879,
#                               'system:index': '2004_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794857520306,
#                'id': 'projects/glad/water/individualMonths/2005_06',
#                'properties': {'system:time_start': 1118793600000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 11178153636,
#                               'system:index': '2005_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794897949698,
#                'id': 'projects/glad/water/individualMonths/2006_06',
#                'properties': {'system:time_start': 1150329600000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 10626272096,
#                               'system:index': '2006_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794934630068,
#                'id': 'projects/glad/water/individualMonths/2007_06',
#                'properties': {'system:time_start': 1181865600000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 10640438986,
#                               'system:index': '2007_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612794973318154,
#                'id': 'projects/glad/water/individualMonths/2008_06',
#                'properties': {'system:time_start': 1213488000000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 11091503279,
#                               'system:index': '2008_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795012298929,
#                'id': 'projects/glad/water/individualMonths/2009_06',
#                'properties': {'system:time_start': 1245024000000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 11020213365,
#                               'system:index': '2009_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795051548717,
#                'id': 'projects/glad/water/individualMonths/2010_06',
#                'properties': {'system:time_start': 1276560000000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 10228531114,
#                               'system:index': '2010_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795090278924,
#                'id': 'projects/glad/water/individualMonths/2011_06',
#                'properties': {'system:time_start': 1308096000000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 10327648831,
#                               'system:index': '2011_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795129521382,
#                'id': 'projects/glad/water/individualMonths/2012_06',
#                'properties': {'system:time_start': 1339718400000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 12165932724,
#                               'system:index': '2012_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795169377735,
#                'id': 'projects/glad/water/individualMonths/2013_06',
#                'properties': {'system:time_start': 1371254400000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13480148906,
#                               'system:index': '2013_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795210263130.0,
#                'id': 'projects/glad/water/individualMonths/2014_06',
#                'properties': {'system:time_start': 1402790400000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13959477673,
#                               'system:index': '2014_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795250583608,
#                'id': 'projects/glad/water/individualMonths/2015_06',
#                'properties': {'system:time_start': 1434326400000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13575474870,
#                               'system:index': '2015_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795288080794,
#                'id': 'projects/glad/water/individualMonths/2016_06',
#                'properties': {'system:time_start': 1465948800000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13523619434,
#                               'system:index': '2016_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1432001, 560001],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             80]}],
#                'version': 1612795327975714,
#                'id': 'projects/glad/water/individualMonths/2017_06',
#                'properties': {'system:time_start': 1497484800000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13756824973,
#                               'system:index': '2017_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1436000, 564000],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             81]}],
#                'version': 1612795367638060.0,
#                'id': 'projects/glad/water/individualMonths/2018_06',
#                'properties': {'system:time_start': 1529020800000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 11171428265,
#                               'system:index': '2018_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1436000, 564000],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             81]}],
#                'version': 1612795407921115,
#                'id': 'projects/glad/water/individualMonths/2019_06',
#                'properties': {'system:time_start': 1560556800000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13306961682,
#                               'system:index': '2019_06'}},
#               {'type': 'Image',
#                'bands': [{'id': 'wp',
#                           'data_type': {'type': 'PixelType',
#                                         'precision': 'int',
#                                         'min': 0,
#                                         'max': 255},
#                           'dimensions': [1436000, 564000],
#                           'crs': 'EPSG:4326',
#                           'crs_transform': [0.00025,
#                                             0,
#                                             -179,
#                                             0,
#                                             -0.00025,
#                                             81]}],
#                'version': 1612795448295321,
#                'id': 'projects/glad/water/individualMonths/2020_06',
#                'properties': {'system:time_start': 1592179200000,
#                               'system:footprint': {'type': 'LinearRing',
#                                                    'coordinates': [[-180, -90],
#                                                                    [180, -90],
#                                                                    [180, 90],
#                                                                    [-180, 90],
#                                                                    [-180,
#                                                                     -90]]},
#                               'system:asset_size': 13558431980,
#                               'system:index': '2020_06'}}]}

# %%
def select_invalid(img, mask_val):
    img_unmasked = img.unmask(mask_val)
    inval_pixels = img_unmasked.eq(mask_val)
    inval_pixels = inval_pixels.updateMask(ee.Image.constant(1))
    return inval_pixels

def mask_invalid(img, mask_val):
    data_mask = img.neq(mask_val)
    data = img.updateMask(data_mask)
    return data

def calc_valid_occurance(img_collection, max_obs, mask_val):
    # Sum the invalid pixels in each image
    invalid_masks = img_collection.map(lambda img: select_invalid(img, mask_val))
    sum_invalid = invalid_masks.reduce(ee.Reducer.sum())

    # Sum the valid water observations in each image
    data = img_collection.map(lambda img: mask_invalid(img, mask_val))
    sum_water = data.reduce(ee.Reducer.sum())

    # Calculate the % valid occurence
    max_obs_img = ee.Image.constant(max_obs)
    denom_img = max_obs_img.subtract(sum_invalid)
    valid_occurence = sum_water.divide(denom_img)

    return valid_occurence



target_imgs = []

for ds in monthly_datasets:
    valid_occurance = calc_valid_occurance(ds[0], ds[1], 255)
    month = ds[2]
    target_imgs.append((valid_occurance, month))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
june = target_imgs[0][0]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
viz_params = {
    'min': 0,
    'max': 22,  
    'palette': ['red', 'yellow', 'blue']
}
Map.addLayer(june, viz_params, 'Summed Image')

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
def export_rois(roi_id, target_img, month):
    
    roi_name_temp = roi_id.split('/')[-1]
    roi_name = roi_name_temp.split('_roi')[0]
    feature = ee.FeatureCollection(roi_id).first()
    bounds = feature.geometry()

    clipped_img = target_img.clip(bounds)

    export_params = {
        'image': clipped_img,
        'description': f'gladFullMonthly_{roi_name}_month_{month}_', 
        'fileNamePrefix': f'gladFullMonthly_{roi_name}_month_{month}_',
        'folder': 'glad_exports', 
        'scale': 30,
        'crs': 'EPSG:4326',
        'region': bounds,
        'fileFormat': 'GeoTIFF',
        'maxPixels': 1e13
    }

    ee.batch.Export.image.toDrive(**export_params).start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
print(target_imgs)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [(<ee.image.Image object at 0x158db2840>, 'june'), (<ee.image.Image object at 0x158db3ce0>, 'aug')]

# %%
for roi_id in rois_ids:
    for img in target_imgs:
        image = img[0]
        month = img[1]
        export_rois(roi_id, image, month)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
